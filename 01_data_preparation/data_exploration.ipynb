# %%
from pyspark.sql import SparkSession

from sarah_hotel_reservation_data.data_processing import HotelDataset

# %%
hotel_data = HotelDataset(
    data_filepath="../data/Hotel Reservations.csv",
    yaml_file_path="../hotel_project_config.yaml",
)
hotel_data.run_data_preparation()

spark = SparkSession.builder.getOrCreate()

hotel_data.save_to_catalog(spark=spark)

# %%
X_train, y_train = hotel_data.get_train_data()

# Inspect the data
X_train.head()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 6922    INN06923             3               0                     0
# 32875   INN32876             2               0                     0
# 31424   INN31425             2               0                     1
# 19532   INN19533             3               0                     0
# 2088    INN02089             2               0                     0
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 6922                   4       Meal Plan 1                           0
# 32875                  1       Meal Plan 1                           0
# 31424                  5       Meal Plan 1                           0
# 19532                  4       Meal Plan 1                           0
# 2088                   0       Meal Plan 1                           0
#
#       room_type_reserved  lead_time  arrival_year  arrival_month  \
# 6922         Room_Type 4         61          2018              6
# 32875        Room_Type 1         26          2018              6
# 31424        Room_Type 1        281          2018             12
# 19532        Room_Type 4          8          2018              2
# 2088         Room_Type 1         12          2018              8
#
#        arrival_date market_segment_type  repeated_guest  \
# 6922              1              Online               0
# 32875             8             Offline               0
# 31424            26              Online               0
# 19532             9              Online               0
# 2088             16              Online               0
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# 6922                              0                                     0
# 32875                             0                                     0
# 31424                             0                                     0
# 19532                             0                                     0
# 2088                              0                                     0
#
#        avg_price_per_room  no_of_special_requests
# 6922               159.30                       1
# 32875              120.00                       0
# 31424               79.62                       2
# 19532              130.00                       1
# 2088                 0.00                       1

# %% [markdown]
# ## Look at each variable

# %%
for column in X_train.columns:
    print(X_train[column].value_counts())
# Out:
# no_of_adults
#  0.298893    16624
# -1.628975     4997
#  2.226761     1488
# -3.556844       98
#  4.154629        9
# Name: count, dtype: int64
# no_of_children
# -0.261470     21459
#  2.222122      1045
#  4.705715       701
#  7.189308         9
#  22.090864        1
#  24.574456        1
# Name: count, dtype: int64
# no_of_weekend_nights
# -0.931190    10955
#  0.217401     6350
#  1.365993     5700
#  2.514584      100
#  3.663175       78
#  4.811767       23
#  5.960358       10
# Name: count, dtype: int64
# no_of_week_nights
# -0.144803     7302
# -0.853578     6075
#  0.563972     5069
#  1.272747     1896
# -1.562353     1535
#  1.981521     1029
#  2.690296      115
#  3.399071       74
#  5.525395       36
#  4.107846       31
#  4.816620       22
#  6.234170       11
#  9.069269        7
#  6.942945        5
#  8.360494        4
#  7.651720        2
#  10.486819       2
#  9.778044        1
# Name: count, dtype: int64
# required_car_parking_space
# -0.178819    22457
#  5.592239      759
# Name: count, dtype: int64
# lead_time
# -0.991888    858
# -0.980250    675
# -0.968613    435
# -0.956976    403
# -0.945338    393
#             ...
#  2.499341      1
#  3.337236      1
#  2.778639      1
#  2.080393      1
#  3.441973      1
# Name: count, Length: 341, dtype: int64
# arrival_year
#  0.467843    19037
# -2.137469     4179
# Name: count, dtype: int64
# arrival_month
#  0.839242    3391
#  0.513493    2978
#  0.187744    2419
# -0.463753    2102
#  1.490739    1903
#  1.164990    1893
# -0.138004    1890
# -1.115250    1734
# -0.789501    1678
# -1.440999    1470
# -1.766747    1100
# -2.092496     658
# Name: count, dtype: int64
# arrival_date
# -0.297128    873
#  0.160521    866
# -1.326838    859
#  0.389345    857
# -1.555662    853
# -1.098013    847
# -0.068304    836
#  0.274933    822
#  0.046109    803
#  0.503757    799
# -0.182716    774
#  1.533467    764
# -0.869189    762
#  1.647879    759
# -0.411540    756
#  1.075818    754
#  0.618170    742
# -1.670074    739
# -0.754777    731
#  1.419055    730
# -1.212425    729
#  0.961406    725
#  1.190231    723
# -0.983601    719
# -0.525952    689
# -1.441250    683
#  1.304643    682
# -0.640365    678
#  0.732582    674
#  0.846994    619
#  1.762292    369
# Name: count, dtype: int64
# repeated_guest
# -0.16221    22613
#  6.16485      603
# Name: count, dtype: int64
# no_of_previous_cancellations
# -0.063393     23004
#  2.651590       128
#  8.081557        25
#  5.366574        24
#  29.801425       14
#  13.511524       10
#  10.796541        9
#  16.226507        1
#  35.231392        1
# Name: count, dtype: int64
# no_of_previous_bookings_not_canceled
# -0.087456     22685
#  0.482621       159
#  1.052699        73
#  1.622777        49
#  2.192855        44
#  2.762933        35
#  3.333010        23
#  3.903088        15
#  4.473166        15
#  5.043244        14
#  5.613322        11
#  6.183399        10
#  8.463711         7
#  6.753477         7
#  7.893633         5
#  10.744022        5
#  7.323555         5
#  9.033788         4
#  11.884177        4
#  10.173944        4
#  13.024333        3
#  11.314100        3
#  9.603866         3
#  24.995967        2
#  16.444800        2
#  12.454255        2
#  14.164489        2
#  27.276278        2
#  20.435344        1
#  19.865267        1
#  32.406978        1
#  13.594411        1
#  22.715656        1
#  15.874722        1
#  24.425889        1
#  26.706200        1
#  32.977056        1
#  31.836900        1
#  18.725111        1
#  25.566045        1
#  19.295189        1
#  23.855811        1
#  30.126667        1
#  14.734566        1
#  17.584955        1
#  27.846356        1
#  28.416434        1
#  29.556589        1
#  31.266823        1
#  28.986511        1
#  26.136122        1
# Name: count, dtype: int64
# avg_price_per_room
# -1.095033    539
# -0.810043    522
# -0.382558    446
# -0.240063    418
#  0.329918    416
#             ...
#  0.084256      1
#  0.274060      1
#  2.746634      1
#  1.385806      1
#  1.073742      1
# Name: count, Length: 3099, dtype: int64
# no_of_special_requests
# -0.788140    12690
#  0.483760     7272
#  1.755661     2771
#  3.027561      427
#  4.299462       49
#  5.571362        7
# Name: count, dtype: int64
# type_of_meal_plan_Meal_Plan_2
# False    21118
# True      2098
# Name: count, dtype: int64
# type_of_meal_plan_Meal_Plan_3
# False    23212
# True         4
# Name: count, dtype: int64
# type_of_meal_plan_Not_Selected
# False    19993
# True      3223
# Name: count, dtype: int64
# room_type_reserved_Room_Type_2
# False    22747
# True       469
# Name: count, dtype: int64
# room_type_reserved_Room_Type_3
# False    23211
# True         5
# Name: count, dtype: int64
# room_type_reserved_Room_Type_4
# False    19401
# True      3815
# Name: count, dtype: int64
# room_type_reserved_Room_Type_5
# False    23033
# True       183
# Name: count, dtype: int64
# room_type_reserved_Room_Type_6
# False    22584
# True       632
# Name: count, dtype: int64
# room_type_reserved_Room_Type_7
# False    23108
# True       108
# Name: count, dtype: int64
# market_segment_type_Complementary
# False    22965
# True       251
# Name: count, dtype: int64
# market_segment_type_Corporate
# False    21884
# True      1332
# Name: count, dtype: int64
# market_segment_type_Offline
# False    16461
# True      6755
# Name: count, dtype: int64
# market_segment_type_Online
# True     14801
# False     8415
# Name: count, dtype: int64
