# %%
from pyspark.sql import SparkSession

from sarah_hotel_reservation_data.data_processing import HotelDataset

# %%
hotel_data = HotelDataset(
    data_filepath="./data/Hotel Reservations.csv",
    yaml_file_path="./hotel_project_config.yaml",
)
hotel_data.run_data_preparation()

# %%
spark = SparkSession.builder.getOrCreate()

# %%
spark

# %%
hotel_data.save_to_catalog(spark=spark)

# %%
X_train, y_train = hotel_data.get_train_data()

# Inspect the data
X_train.head()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 6922       2.226761        -0.26147             -0.931190           1.272747
# 32875      0.298893        -0.26147             -0.931190          -0.853578
# 31424      0.298893        -0.26147              0.217401           1.981521
# 19532      2.226761        -0.26147             -0.931190           1.272747
# 2088       0.298893        -0.26147             -0.931190          -1.562353
#
#        required_car_parking_space  lead_time  arrival_year  arrival_month  \
# 6922                    -0.178819  -0.282005      0.467843      -0.463753
# 32875                   -0.178819  -0.689315      0.467843      -0.463753
# 31424                   -0.178819   2.278230      0.467843       1.490739
# 19532                   -0.178819  -0.898788      0.467843      -1.766747
# 2088                    -0.178819  -0.852239      0.467843       0.187744
#
#        arrival_date  repeated_guest  ...  room_type_reserved_Room_Type 2  \
# 6922      -1.670074        -0.16221  ...                           False
# 32875     -0.869189        -0.16221  ...                           False
# 31424      1.190231        -0.16221  ...                           False
# 19532     -0.754777        -0.16221  ...                           False
# 2088       0.046109        -0.16221  ...                           False
#
#        room_type_reserved_Room_Type 3  room_type_reserved_Room_Type 4  \
# 6922                            False                            True
# 32875                           False                           False
# 31424                           False                           False
# 19532                           False                            True
# 2088                            False                           False
#
#        room_type_reserved_Room_Type 5  room_type_reserved_Room_Type 6  \
# 6922                            False                           False
# 32875                           False                           False
# 31424                           False                           False
# 19532                           False                           False
# 2088                            False                           False
#
#        room_type_reserved_Room_Type 7  market_segment_type_Complementary  \
# 6922                            False                              False
# 32875                           False                              False
# 31424                           False                              False
# 19532                           False                              False
# 2088                            False                              False
#
#        market_segment_type_Corporate  market_segment_type_Offline  \
# 6922                           False                        False
# 32875                          False                         True
# 31424                          False                        False
# 19532                          False                        False
# 2088                           False                        False
#
#        market_segment_type_Online
# 6922                         True
# 32875                       False
# 31424                        True
# 19532                        True
# 2088                         True
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Look at each variable

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# Booking_ID
# INN00001    1
# INN24187    1
# INN24181    1
# INN24182    1
# INN24183    1
#            ..
# INN12086    1
# INN12085    1
# INN12084    1
# INN12083    1
# INN36275    1
# Name: count, Length: 36275, dtype: int64
# no_of_adults
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: count, dtype: int64
# no_of_children
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64
# no_of_weekend_nights
# 0    16872
# 1     9995
# 2     9071
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: count, dtype: int64
# no_of_week_nights
# 2     11444
# 1      9488
# 3      7839
# 4      2990
# 0      2387
# 5      1614
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: count, dtype: int64
# type_of_meal_plan
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: count, dtype: int64
# required_car_parking_space
# 0    35151
# 1     1124
# Name: count, dtype: int64
# room_type_reserved
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64
# lead_time
# 0      1297
# 1      1078
# 2       643
# 3       630
# 4       628
#        ...
# 300       1
# 353       1
# 328       1
# 352       1
# 351       1
# Name: count, Length: 352, dtype: int64
# arrival_year
# 2018    29761
# 2017     6514
# Name: count, dtype: int64
# arrival_month
# 10    5317
# 9     4611
# 8     3813
# 6     3203
# 12    3021
# 11    2980
# 7     2920
# 4     2736
# 5     2598
# 3     2358
# 2     1704
# 1     1014
# Name: count, dtype: int64
# arrival_date
# 13    1358
# 17    1345
# 2     1331
# 4     1327
# 19    1327
# 16    1306
# 20    1281
# 15    1273
# 6     1273
# 18    1260
# 14    1242
# 30    1216
# 12    1204
# 8     1198
# 29    1190
# 21    1158
# 5     1154
# 26    1146
# 25    1146
# 1     1133
# 9     1130
# 28    1129
# 7     1110
# 24    1103
# 11    1098
# 3     1098
# 10    1089
# 27    1059
# 22    1023
# 23     990
# 31     578
# Name: count, dtype: int64
# market_segment_type
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: count, dtype: int64
# repeated_guest
# 0    35345
# 1      930
# Name: count, dtype: int64
# no_of_previous_cancellations
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: count, dtype: int64
# no_of_previous_bookings_not_canceled
# 0     35463
# 1       228
# 2       112
# 3        80
# 4        65
# 5        60
# 6        36
# 7        24
# 8        23
# 10       19
# 9        19
# 11       15
# 12       12
# 14        9
# 15        8
# 16        7
# 13        7
# 18        6
# 20        6
# 21        6
# 17        6
# 19        6
# 22        6
# 25        3
# 27        3
# 24        3
# 23        3
# 44        2
# 29        2
# 48        2
# 28        2
# 30        2
# 32        2
# 31        2
# 26        2
# 46        1
# 55        1
# 45        1
# 57        1
# 53        1
# 54        1
# 58        1
# 41        1
# 40        1
# 43        1
# 35        1
# 50        1
# 56        1
# 33        1
# 37        1
# 42        1
# 51        1
# 38        1
# 34        1
# 39        1
# 52        1
# 49        1
# 47        1
# 36        1
# Name: count, dtype: int64
# avg_price_per_room
# 65.00     848
# 75.00     826
# 90.00     703
# 95.00     669
# 115.00    662
#          ...
# 212.42      1
# 83.48       1
# 70.42       1
# 130.99      1
# 167.80      1
# Name: count, Length: 3930, dtype: int64
# no_of_special_requests
# 0    19777
# 1    11373
# 2     4364
# 3      675
# 4       78
# 5        8
# Name: count, dtype: int64
# booking_status
# Not_Canceled    24390
# Canceled        11885
# Name: count, dtype: int64
