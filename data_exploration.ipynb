# %%
from hotel_data_preprocessing.src.data_processing import (
    load_dataset,
    split_dataset_into_X_and_y,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from hotel_data_preprocessing.src.data_processing import (
#       2     load_dataset,
#       3     split_dataset_into_X_and_y,
#       4 )
#
# ModuleNotFoundError: No module named 'hotel_data_preprocessing'

# %%
# Load the dataset
df = load_dataset("./data/Hotel Reservations.csv")

# Inspect the data
print(df.info())
print(df.describe())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
X, y = split_dataset_into_X_and_y(df, target_column_name="booking_status")
X
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
# find connection between booking_status and arrival_month

# %% [markdown]
# ## Look at each variable

# %%
for column in df.columns:
    print(df[column].value_counts())
# Out:
# Booking_ID
# INN00001    1
# INN24187    1
# INN24181    1
# INN24182    1
# INN24183    1
#            ..
# INN12086    1
# INN12085    1
# INN12084    1
# INN12083    1
# INN36275    1
# Name: count, Length: 36275, dtype: int64
# no_of_adults
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: count, dtype: int64
# no_of_children
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64
# no_of_weekend_nights
# 0    16872
# 1     9995
# 2     9071
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: count, dtype: int64
# no_of_week_nights
# 2     11444
# 1      9488
# 3      7839
# 4      2990
# 0      2387
# 5      1614
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: count, dtype: int64
# type_of_meal_plan
# Meal Plan 1     27835
# Not Selected     5130
# ...
